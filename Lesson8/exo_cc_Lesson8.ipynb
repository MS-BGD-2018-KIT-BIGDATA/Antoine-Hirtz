# %%
import pandas as pd

# %%
# DONNEES 2016 - Densité de médecins pour 100.000 habitants

file = "rpps-medecins-tab7_46225962429478"
root = "/Users/antoinehirtz/Documents/GitHub/ms-bgd-myrepo/Lesson7/"
filename = root + file
doctors = pd.read_csv(filename + ".csv", sep=',', header=3, encoding='latin_1')

# %%
doctors = doctors.drop(doctors.index[[0]])

# %%
doctors
# Out:
#                               SPECIALITE  Ensemble des spécialités d'exercice  \
# 1                         FRANCE ENTIERE                                336.8
# 2                  FRANCE Métropolitaine                                339.2
# 3                                DOM-COM                                264.0
# 4      Alsace-Champagne-Ardenne-Lorraine                                319.9
# 5    Aquitaine-Limousin-Poitou-Charentes                                334.4
# 6                   Auvergne-Rhône-Alpes                                336.9
# 7                Bourgogne-Franche-Comté                                294.6
# 8                               Bretagne                                315.7
# 9                    Centre-Val de Loire                                268.0
# 10                                 Corse                                298.3
# 11                            Guadeloupe                                267.7
# ...

# %%
doctors.pivot(index='SPECIALITE', columns='spécialiste')
# Out:
#              Ensemble des spécialités d'exercice                         \
# SPECIALITE                              01 - Ain 02 - Aisne 03 - Allier
# Spécialistes
# 30.0                                         NaN        NaN         NaN
# 73.4                                         NaN        NaN         NaN
# 78.2                                         NaN        NaN         NaN
# 81.1                                       188.0        NaN         NaN
# 85.4                                         NaN        NaN         NaN
# 85.5                                         NaN        NaN         NaN
# 86.4                                         NaN        NaN         NaN
# 87.7                                         NaN        NaN         NaN
# 90.4                                         NaN        NaN         NaN
# 94.8                                         NaN        NaN         NaN
# 97.1                                         NaN        NaN         NaN
# ...
