# %%
import requests
import json
import pandas as pd
import numpy as np
import string
import re

# %%
regex = re.compile('\d+')
regex_dose = re.compile('\d+,?\d* ?m?[g|l]\/?m?l?')
regex_ans = re.compile('(\d+) ans')
regex_kg = re.compile('(\d+) kg')

# %%
def get_info(codeCIS):
    url = 'https://www.open-medicaments.fr/api/v1/medicaments/' + codeCIS
    result = requests.get(url)
    response_result = json.loads(result.text)
    
    try:
        libelle = response_result['presentations'][0]['libelle']
        quantite = int(regex.findall(libelle)[0])
    except:
        quantite = np.nan
        
    try:
        date = response_result['presentations'][0]['dateDeclarationCommercialisation']
    except:
        date = ''

    try:
        denomination = response_result['denomination']
    except:
        denomination = ''
    
    try:
        dose_unite = regex_dose.findall(denomination)
        unite = dose_unite[0].split()[1]
        dose = int(dose_unite[0].split()[0])
        if unite == 'g': dose *= 1000
    except:
        dose = np.nan
    
    try:
        indication = response_result['indicationsTherapeutiques']
        indic_ans = regex_ans.findall(indication)
        indic_ans = np.nan if indic_ans == [] else indic_ans[0]
        indic_kg = regex_kg.findall(indication)
        indic_kg = np.nan if indic_kg == [] else indic_kg[0]
    except:
        indic_ans = np.nan
        indic_kg = np.nan
    
    return pd.DataFrame([[codeCIS,
                          denomination,
                          dose,
                          quantite,
                          pd.to_datetime(date),
                          indic_ans,
                          indic_kg]],
                        columns=col)

# %%
def get_codesCIS():
    codesCIS = []
    for letter in string.ascii_lowercase:
        search_url =  "https://www.open-medicaments.fr/api/v1/medicaments?query=" + letter
        result_search = requests.get(search_url)
        response = json.loads(result_search.text)
        codesCIS.append(pd.DataFrame.from_dict(response).codeCIS.values.tolist())

    return np.array(codesCIS).reshape(-1, 1).flatten().tolist()

# %%
def get_infos_medicaments():
    infos = pd.DataFrame(columns=col)
    for medicament in get_codesCIS():
        infos = infos.append(get_info(medicament), ignore_index=True)
    infos.set_index('codeCIS', inplace=True)
    
    return infos

# %%
col = ["codeCIS", "denomination", "dose", "quantite", "date", "indic_age_min", "indic_kg_min"]

results = get_infos_medicaments()

# %%
results
# Out:
#                                                denomination dose quantite  \
# codeCIS
# 66862795  ALPHACAINE N, solution injectable à usage dent...  NaN        1
# 63092688       ACECLOFENAC MYLAN 100 mg, comprimé pelliculé  100       30
# 62887979            ACETYLLEUCINE BIOGARAN 500 mg, comprimé  500       30
# 65319558    ACECLOFENAC QUALIMED 100 mg, comprimé pelliculé  100       30
# 69771614                    ACARBOSE SANDOZ 50 mg, comprimé   50       90
# 60946941            ACARBOSE MYLAN 100 mg, comprimé sécable  100       90
# 65999182                  ADAPALENE TEVA 0,1 POUR CENT, gel  NaN       30
# 61683272                   ACICLOVIR ALMUS 200 mg, comprimé  200       25
# 64728712                           ABUFENE 400 mg, comprimé  400       60
# 68933636                         ACTIVIR 5 POUR CENT, crème  NaN        1
# 69724187  ACAMPROSATE BIOGARAN 333 mg, comprimé pellicul...  333       60
# 65991463         ALPRAZOLAM ZYDUS 0,25 mg, comprimé sécable  NaN        1
# 64654920        ALPRAZOLAM ISOMED 0,50 mg, comprimé sécable  NaN       30
# 65868763      ALPRAZOLAM CRISTERS 0,50 mg, comprimé sécable  NaN       30
# 68425029          ALPRAZOLAM TEVA 0,50 mg, comprimé sécable  NaN       30
# 61346771      ALPRAZOLAM CRISTERS 0,25 mg, comprimé sécable  NaN       30
# 61136285           ALPRAZOLAM RPG 0,50 mg, comprimé sécable  NaN       30
# 61200859         ALPRAZOLAM MYLAN 0,50 mg, comprimé sécable  NaN        1
# 64275767         ALPRAZOLAM ARROW 0,50 mg, comprimé sécable  NaN       30
# 65515119      ALPRAZOLAM EVOLUGEN 0,50 mg, comprimé sécable  NaN       30
# 60443192                             B O P, comprimé enrobé  NaN        1
# 64493883  BEXSERO suspension injectable en seringue prér...  NaN        1
# 65569259  BICARBONATE DE SODIUM 4,2 POUR CENT B. BRAUN, ...  NaN       10
# 62472716      BACLOFENE SUN 0,05 mg/ml, solution injectable  NaN        1
# 64073783          BACLOFENE ZENTIVA 10 mg, comprimé sécable   10       30
# 60973899  BCG-MEDAC, poudre et solvant pour suspension p...  NaN        1
# 61835424  BACLOFENE SUN 10 mg/5 ml, solution pour perfusion   10        1
# 61434805  BACLOFENE SUN 10 mg/20 ml, solution pour perfu...   10        1
# 67025142                            BASDENE 25 mg, comprimé   25        2
# 63914016  BACLOFENE AGUETTANT 2 mg/ml, solution pour per...    2       10
# ...                                                     ...  ...      ...
# 60457338  YONDELIS 1 mg, poudre pour solution à diluer p...    1        1
# 65491383  YTRACIS, précurseur radiopharmaceutique, en so...  NaN        1
# 64304674              YELLOX 0,9 mg/ml, collyre en solution  NaN        1
# 64234891  MENCEVAX, poudre et solvant pour solution inje...  NaN        1
# 68657821    YRANICID SANS ARSENIC, pâte pour usage dentaire  NaN        1
# 69214070          YDRALBUM 200 g/l, solution pour perfusion  200        1
# 65008219      YERBALAXA, plantes pour tisane en sachet dose  NaN       10
# 64791997      YRANOL EUGENOLE, solution pour usage dentaire  NaN        1
# 69241562  NIMENRIX, poudre et solvant pour solution inje...  NaN        1
# 68046787  MENVEO, poudre et solution pour solution injec...  NaN        1
# 64122807                            ZONEGRAN 100 mg, gélule  100       56
# 69287499                             ZONEGRAN 50 mg, gélule   50       14
# 61088036                             ZONEGRAN 25 mg, gélule   25       14
# 65883886  ZOPICLONE ZYDUS 7,5 mg, comprimé pelliculé séc...  NaN       14
# 68354386           ZOMIGORO 2,5 mg, comprimé orodispersible  NaN        6
# 65066770  ZOPICLONE ZENTIVA 7,5 mg, comprimé pelliculé s...  NaN        5
# 60946507  ZOLMITRIPTAN ZENTIVA 2,5 mg, comprimé orodispe...  NaN        6
# 63369594    ZOLMITRIPTAN ZENTIVA 2,5 mg, comprimé pelliculé  NaN        6
# 62048087  ZOPICLONE BIOGARAN 7,5 mg, comprimé pelliculé ...  NaN       14
# 60976557    ZOPICLONE EG 7,5 mg, comprimé pelliculé sécable  NaN       14
# 66473032  ZOPICLONE SANDOZ 7,5 mg, comprimé pelliculé sé...  NaN       14
# 68466944  ZOPICLONE ARROW 7,5 mg, comprimé pelliculé séc...  NaN       14
# 61417784  ZOPICLONE RANBAXY 7,5 mg, comprimé pelliculé s...  NaN       14
# 68606225                   ZOLMITRIPTAN EG 2,5 mg, comprimé  NaN        6
# 68232350                   ZOMIG 2,5 mg, comprimé pelliculé  NaN        6
# 67050829  ZOLMITRIPTAN BIOGARAN 2,5 mg, comprimé orodisp...  NaN        6
# 60462513  ZOLMITRIPTAN CRISTERS 2,5 mg, comprimé orodisp...  NaN       12
# 67038894  ZOLMITRIPTAN EVOLUGEN 2,5 mg, comprimé orodisp...  NaN        6
# 69058237  ZOLMITRIPTAN SANDOZ 2,5 mg, comprimé orodisper...  NaN        6
# 63083116     ZOLMITRIPTAN SANDOZ 2,5 mg, comprimé pelliculé  NaN        6
#
#                date indic_age_min indic_kg_min
# codeCIS
# 66862795 1981-01-01           NaN          NaN
# 63092688 2008-04-08           NaN          NaN
# 62887979 2012-02-01           NaN          NaN
# 65319558 2012-07-17           NaN          NaN
# 69771614 2015-08-21           NaN          NaN
# 60946941 2014-02-26           NaN          NaN
# 65999182 2013-07-17           NaN          NaN
# 61683272 2015-02-05           NaN          NaN
# 64728712 2013-03-27           NaN          NaN
# 68933636 1997-01-19           NaN          NaN
# 69724187 2015-03-19           NaN          NaN
# 65991463 2004-09-20           NaN          NaN
# 64654920 2014-07-08           NaN          NaN
# 65868763 2009-04-28           NaN          NaN
# 68425029 2004-02-06           NaN          NaN
# 61346771 2009-04-28           NaN          NaN
# 61136285 2013-07-30           NaN          NaN
# 61200859 2013-08-28           NaN          NaN
# 64275767 2005-07-27           NaN          NaN
# 65515119 2014-10-03           NaN          NaN
# 60443192 1972-01-19           NaN          NaN
# 64493883 2013-12-09           NaN          NaN
# 65569259 2010-12-01           NaN          NaN
# 62472716 2010-09-16            18          NaN
# 64073783 2006-01-05            18          NaN
# 60973899 2016-02-15           NaN          NaN
# 61835424 2010-09-16            18          NaN
# 61434805 2010-09-16            18          NaN
# 67025142 1950-01-19           NaN          NaN
# 63914016 2012-12-17            18          NaN
# ...             ...           ...          ...
# 60457338 2007-12-13           NaN          NaN
# 65491383 2003-10-06           NaN          NaN
# 64304674 2012-09-06           NaN          NaN
# 64234891 2013-12-19             2          NaN
# 68657821 2012-09-12           NaN          NaN
# 69214070 2012-06-14           NaN          NaN
# 65008219 1999-02-19           NaN          NaN
# 64791997 2015-06-08           NaN          NaN
# 69241562 2012-11-29           NaN          NaN
# 68046787 2012-12-17           NaN          NaN
# 64122807 2006-01-16           NaN          NaN
# 69287499 2006-01-16           NaN          NaN
# 61088036 2006-01-16           NaN          NaN
# 65883886 2004-11-05           NaN          NaN
# 68354386 2000-10-23           NaN          NaN
# 65066770 2010-03-09           NaN          NaN
# 60946507 2012-03-09           NaN          NaN
# 63369594 2012-03-09           NaN          NaN
# 62048087 2015-08-21           NaN          NaN
# 60976557 2000-08-01           NaN          NaN
# 66473032 2005-07-18           NaN          NaN
# 68466944 2002-06-12           NaN          NaN
# 61417784 2009-10-08           NaN          NaN
# 68606225 2012-03-12           NaN          NaN
# 68232350 1998-06-01           NaN          NaN
# 67050829 2012-03-08           NaN          NaN
# 60462513 2012-10-26           NaN          NaN
# 67038894 2012-03-14           NaN          NaN
# 69058237 2012-11-07           NaN          NaN
# 63083116 2012-10-08           NaN          NaN
#
# [520 rows x 6 columns]
