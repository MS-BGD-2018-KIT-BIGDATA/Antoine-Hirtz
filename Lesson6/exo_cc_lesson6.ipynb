# %% [markdown]
# # Scraping _OPEN MEDICAMENTS_ (via API)

# %%
import requests
import json
import pandas as pd
import numpy as np
import string
import re
import itertools
from decimal import Decimal

# %%
regex = re.compile('\d+')
regex_nom = re.compile('[A-Z ]+')
regex_dose = re.compile('\d+,?\d* ?m?[g|l]\/?m?l?')
regex_ans = re.compile('(\d+) ans')
regex_kg = re.compile('(\d+) kg')

# %%
def get_info(codeCIS):
    url = 'https://www.open-medicaments.fr/api/v1/medicaments/' + codeCIS
    result = requests.get(url)
    response_result = json.loads(result.text)
    
    try:
        libelle = response_result['presentations'][0]['libelle']
        quantite = int(regex.findall(libelle)[0])
    except:
        quantite = np.nan
        
    try:
        date = response_result['presentations'][0]['dateDeclarationCommercialisation']
    except:
        date = ''

    try:
        denomination = response_result['denomination']
    except:
        denomination = ''
        
    try:
        nom = regex_nom.findall(denomination)[0]
        etiquette = denomination.replace(nom + ',', '').replace(nom, '')
    except:
        nom = ''
        
    try:
        nom = regex_nom.findall(denomination)[0]
    except:
        nom = ''
    
    try:
        dose_unite = regex_dose.findall(denomination)
        unite = dose_unite[0].split(' ')[1]
        dose = Decimal(dose_unite[0].split(' ')[0].replace(',', '.'))
        if unite == 'g': dose *= 1000
    except:
        dose = np.nan
    
    try:
        indication = response_result['indicationsTherapeutiques']
        indic_ans = regex_ans.findall(indication)
        indic_ans = np.nan if indic_ans == [] else indic_ans[0]
        indic_kg = regex_kg.findall(indication)
        indic_kg = np.nan if indic_kg == [] else indic_kg[0]
    except:
        indic_ans = np.nan
        indic_kg = np.nan
    
    return pd.DataFrame([[codeCIS,
                          nom,
                          etiquette,
                          dose,
                          quantite,
                          pd.to_datetime(date),
                          indic_ans,
                          indic_kg]],
                        columns=col)

# %%
def get_codesCIS():
    codesCIS = []
    for letter in string.ascii_lowercase:
        search_url =  "https://www.open-medicaments.fr/api/v1/medicaments?query=" + letter
        result_search = requests.get(search_url)
        response = json.loads(result_search.text)
        codesCIS.append(pd.DataFrame.from_dict(response).codeCIS.values.tolist())

    return list(itertools.chain.from_iterable(codesCIS))

# %%
def get_infos_medicaments():
    infos = pd.DataFrame(columns=col)
    for medicament in get_codesCIS():
        infos = infos.append(get_info(medicament), ignore_index=True)
    infos.set_index('codeCIS', inplace=True)
    
    return infos

# %%
col = ["codeCIS", "nom", "etiquette", "dose", "quantite", "date", "indic_age_min", "indic_kg_min"]

results = get_infos_medicaments()

# %%
results
# Out:
#                               nom  \
# codeCIS
# 66862795             ALPHACAINE N
# 63092688       ACECLOFENAC MYLAN
# 62887979  ACETYLLEUCINE BIOGARAN
# 65319558    ACECLOFENAC QUALIMED
# 69771614         ACARBOSE SANDOZ
# 60946941          ACARBOSE MYLAN
# 65999182          ADAPALENE TEVA
# 61683272         ACICLOVIR ALMUS
# 64728712                 ABUFENE
# 68933636                 ACTIVIR
# 69724187    ACAMPROSATE BIOGARAN
# 65991463        ALPRAZOLAM ZYDUS
# 64654920       ALPRAZOLAM ISOMED
# 65868763     ALPRAZOLAM CRISTERS
# 68425029         ALPRAZOLAM TEVA
# 61346771     ALPRAZOLAM CRISTERS
# 61136285          ALPRAZOLAM RPG
# 61200859        ALPRAZOLAM MYLAN
# 64275767        ALPRAZOLAM ARROW
# 65515119     ALPRAZOLAM EVOLUGEN
# 60443192                    B O P
# 64493883                 BEXSERO
# 65569259   BICARBONATE DE SODIUM
# 62472716           BACLOFENE SUN
# 64073783       BACLOFENE ZENTIVA
# 60973899                      BCG
# 61835424           BACLOFENE SUN
# 61434805           BACLOFENE SUN
# 67025142                 BASDENE
# 63914016     BACLOFENE AGUETTANT
# ...                           ...
# 60457338                YONDELIS
# 65491383                  YTRACIS
# 64304674                  YELLOX
# 64234891                 MENCEVAX
# 68657821    YRANICID SANS ARSENIC
# 69214070                YDRALBUM
# 65008219                YERBALAXA
# 64791997          YRANOL EUGENOLE
# 69241562                 NIMENRIX
# 68046787                   MENVEO
# 64122807                ZONEGRAN
# 69287499                ZONEGRAN
# 61088036                ZONEGRAN
# 65883886         ZOPICLONE ZYDUS
# 68354386                ZOMIGORO
# 65066770       ZOPICLONE ZENTIVA
# 60946507    ZOLMITRIPTAN ZENTIVA
# 63369594    ZOLMITRIPTAN ZENTIVA
# 62048087      ZOPICLONE BIOGARAN
# 60976557            ZOPICLONE EG
# 66473032        ZOPICLONE SANDOZ
# 68466944         ZOPICLONE ARROW
# 61417784       ZOPICLONE RANBAXY
# 68606225         ZOLMITRIPTAN EG
# 68232350                   ZOMIG
# 67050829   ZOLMITRIPTAN BIOGARAN
# 60462513   ZOLMITRIPTAN CRISTERS
# 67038894   ZOLMITRIPTAN EVOLUGEN
# 69058237     ZOLMITRIPTAN SANDOZ
# 63083116     ZOLMITRIPTAN SANDOZ
#
#                                                   etiquette  dose quantite  \
# codeCIS
# 66862795               solution injectable à usage dentaire   NaN        1
# 63092688                         100 mg, comprimé pelliculé   100       30
# 62887979                                   500 mg, comprimé   500       30
# 65319558                         100 mg, comprimé pelliculé   100       30
# 69771614                                    50 mg, comprimé    50       90
# 60946941                           100 mg, comprimé sécable   100       90
# 65999182                                 0,1 POUR CENT, gel   NaN       30
# 61683272                                   200 mg, comprimé   200       25
# 64728712                                   400 mg, comprimé   400       60
# 68933636                                 5 POUR CENT, crème   NaN        1
# 69724187        333 mg, comprimé pelliculé gastro-résistant   333       60
# 65991463                          0,25 mg, comprimé sécable  0.25        1
# 64654920                          0,50 mg, comprimé sécable  0.50       30
# 65868763                          0,50 mg, comprimé sécable  0.50       30
# 68425029                          0,50 mg, comprimé sécable  0.50       30
# 61346771                          0,25 mg, comprimé sécable  0.25       30
# 61136285                          0,50 mg, comprimé sécable  0.50       30
# 61200859                          0,50 mg, comprimé sécable  0.50        1
# 64275767                          0,50 mg, comprimé sécable  0.50       30
# 65515119                          0,50 mg, comprimé sécable  0.50       30
# 60443192                                    comprimé enrobé   NaN        1
# 64493883  suspension injectable en seringue préremplie. ...   NaN        1
# 65569259    4,2 POUR CENT B. BRAUN, solution pour perfusion   NaN       10
# 62472716                    0,05 mg/ml, solution injectable  0.05        1
# 64073783                            10 mg, comprimé sécable    10       30
# 60973899  -MEDAC, poudre et solvant pour suspension pour...   NaN        1
# 61835424                10 mg/5 ml, solution pour perfusion    10        1
# 61434805               10 mg/20 ml, solution pour perfusion    10        1
# 67025142                                    25 mg, comprimé    25        2
# 63914016  2 mg/ml, solution pour perfusion pour voie int...     2       10
# ...                                                     ...   ...      ...
# 60457338  1 mg, poudre pour solution à diluer pour perfu...     1        1
# 65491383        précurseur radiopharmaceutique, en solution   NaN        1
# 64304674                     0,9 mg/ml, collyre en solution   0.9        1
# 64234891   poudre et solvant pour solution injectable. V...   NaN        1
# 68657821                           pâte pour usage dentaire   NaN        1
# 69214070                   200 g/l, solution pour perfusion   200        1
# 65008219                 plantes pour tisane en sachet dose   NaN       10
# 64791997                       solution pour usage dentaire   NaN        1
# 69241562   poudre et solvant pour solution injectable. V...   NaN        1
# 68046787   poudre et solution pour solution injectable. ...   NaN        1
# 64122807                                     100 mg, gélule   100       56
# 69287499                                      50 mg, gélule    50       14
# 61088036                                      25 mg, gélule    25       14
# 65883886                 7,5 mg, comprimé pelliculé sécable   7.5       14
# 68354386                    2,5 mg, comprimé orodispersible   2.5        6
# 65066770                 7,5 mg, comprimé pelliculé sécable   7.5        5
# 60946507                    2,5 mg, comprimé orodispersible   2.5        6
# 63369594                         2,5 mg, comprimé pelliculé   2.5        6
# 62048087                 7,5 mg, comprimé pelliculé sécable   7.5       14
# 60976557                 7,5 mg, comprimé pelliculé sécable   7.5       14
# 66473032                 7,5 mg, comprimé pelliculé sécable   7.5       14
# 68466944                 7,5 mg, comprimé pelliculé sécable   7.5       14
# 61417784                 7,5 mg, comprimé pelliculé sécable   7.5       14
# 68606225                                   2,5 mg, comprimé   2.5        6
# 68232350                         2,5 mg, comprimé pelliculé   2.5        6
# 67050829                    2,5 mg, comprimé orodispersible   2.5        6
# 60462513                    2,5 mg, comprimé orodispersible   2.5       12
# 67038894                    2,5 mg, comprimé orodispersible   2.5        6
# 69058237                    2,5 mg, comprimé orodispersible   2.5        6
# 63083116                         2,5 mg, comprimé pelliculé   2.5        6
#
#                date indic_age_min indic_kg_min
# codeCIS
# 66862795 1981-01-01           NaN          NaN
# 63092688 2008-04-08           NaN          NaN
# 62887979 2012-02-01           NaN          NaN
# 65319558 2012-07-17           NaN          NaN
# 69771614 2015-08-21           NaN          NaN
# 60946941 2014-02-26           NaN          NaN
# 65999182 2013-07-17           NaN          NaN
# 61683272 2015-02-05           NaN          NaN
# 64728712 2013-03-27           NaN          NaN
# 68933636 1997-01-19           NaN          NaN
# 69724187 2015-03-19           NaN          NaN
# 65991463 2004-09-20           NaN          NaN
# 64654920 2014-07-08           NaN          NaN
# 65868763 2009-04-28           NaN          NaN
# 68425029 2004-02-06           NaN          NaN
# 61346771 2009-04-28           NaN          NaN
# 61136285 2013-07-30           NaN          NaN
# 61200859 2013-08-28           NaN          NaN
# 64275767 2005-07-27           NaN          NaN
# 65515119 2014-10-03           NaN          NaN
# 60443192 1972-01-19           NaN          NaN
# 64493883 2013-12-09           NaN          NaN
# 65569259 2010-12-01           NaN          NaN
# 62472716 2010-09-16            18          NaN
# 64073783 2006-01-05            18          NaN
# 60973899 2016-02-15           NaN          NaN
# 61835424 2010-09-16            18          NaN
# 61434805 2010-09-16            18          NaN
# 67025142 1950-01-19           NaN          NaN
# 63914016 2012-12-17            18          NaN
# ...             ...           ...          ...
# 60457338 2007-12-13           NaN          NaN
# 65491383 2003-10-06           NaN          NaN
# 64304674 2012-09-06           NaN          NaN
# 64234891 2013-12-19             2          NaN
# 68657821 2012-09-12           NaN          NaN
# 69214070 2012-06-14           NaN          NaN
# 65008219 1999-02-19           NaN          NaN
# 64791997 2015-06-08           NaN          NaN
# 69241562 2012-11-29           NaN          NaN
# 68046787 2012-12-17           NaN          NaN
# 64122807 2006-01-16           NaN          NaN
# 69287499 2006-01-16           NaN          NaN
# 61088036 2006-01-16           NaN          NaN
# 65883886 2004-11-05           NaN          NaN
# 68354386 2000-10-23           NaN          NaN
# 65066770 2010-03-09           NaN          NaN
# 60946507 2012-03-09           NaN          NaN
# 63369594 2012-03-09           NaN          NaN
# 62048087 2015-08-21           NaN          NaN
# 60976557 2000-08-01           NaN          NaN
# 66473032 2005-07-18           NaN          NaN
# 68466944 2002-06-12           NaN          NaN
# 61417784 2009-10-08           NaN          NaN
# 68606225 2012-03-12           NaN          NaN
# 68232350 1998-06-01           NaN          NaN
# 67050829 2012-03-08           NaN          NaN
# 60462513 2012-10-26           NaN          NaN
# 67038894 2012-03-14           NaN          NaN
# 69058237 2012-11-07           NaN          NaN
# 63083116 2012-10-08           NaN          NaN
#
# [520 rows x 7 columns]

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 520 entries, 66862795 to 63083116
# Data columns (total 7 columns):
# nom              520 non-null object
# etiquette        520 non-null object
# dose             339 non-null object
# quantite         493 non-null object
# date             493 non-null datetime64[ns]
# indic_age_min    59 non-null object
# indic_kg_min     6 non-null object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 32.5+ KB

# %%
results.to_csv('/Users/antoinehirtz/Documents/openmedicaments.csv', encoding='utf-8-sig')
